# %% [markdown]
# <a href="https://colab.research.google.com/github/angelomarcelino/machine_learning/blob/main/q3_espirals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Questão 3
# Considere o problema de classificação de padrões constituído por duas espirais intercaladas. A espiral 1 sendo a classe 1 e a espiral 2 sendo a classe 2. Gere os exemplos de treinamento usando as seguintes equações:
#
# para espiral 1, $x = \dfrac{\theta}{4}\text{cos}\theta$ &nbsp;&nbsp;&nbsp;&nbsp; $y = \dfrac{\theta}{4}\text{sen}\theta$ &nbsp;&nbsp;&nbsp;&nbsp; $\theta \geq 0$
#
#
# para espiral 2, $x = (\dfrac{\theta}{4} + 0.8)\text{cos}\theta$ &nbsp;&nbsp;&nbsp;&nbsp; $y = (\dfrac{\theta}{4} + 0.8)\text{sen}\theta$ &nbsp;&nbsp;&nbsp;&nbsp; $\theta \geq 0$
#
#
# fazendo $\theta$ assumir valores igualmente espaçados entre 0 e 20 radianos. Compare o desempenho das soluções com base na matriz de confusão. Pesquise e utilize uma rede convolutiva já treinada.

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import numpy as np

# %%
# Definindo as espirais
theta = np.linspace(0, 20, 1000)

x1, y1 = ((theta/4)*np.cos(theta), (theta/4)*np.sin(theta))
x2, y2 = (((theta/4)+.8)*np.cos(theta), ((theta/4)+.8)*np.sin(theta))

plt.rcParams.update({'font.size': 24})
fig, axes = plt.subplots(figsize=(18, 10))

axes.scatter(x1, y1, s=50, label='Classe 0')
axes.scatter(x2, y2, s=50, label='Classe 1')

axes.set(
    title='Dataset',
    xlabel='x',
    ylabel='y'
)

plt.legend()
plt.show()

# %% [markdown]
# ### Feature Engineering
#
# Mais duas features serão adicionadas ao dataset com o objetivo de ajudar a modelegem do problema, são elas $arctan2(y, x)$ e $\sqrt{x^2 + y^2}$ que equivalem a transformação em coordenadas esféricas.

# %%
import pandas as pd

x = np.concatenate([x1, x2])
y = np.concatenate([y1, y2])

dataset = pd.DataFrame({
    'x': x,
    'y': y,
    'x2': x**2,
    'y2': y**2,
    'arctan': np.arctan2(y, x),
    'norm': np.sqrt(x**2 + y**2),
    'label': [0]*len(theta) + [1]*len(theta) 
})

x_train, x_test, y_train, y_test = train_test_split(dataset.drop(['label'], axis=1), dataset['label'], test_size=0.2, random_state=505)
x_train.drop(['x', 'y'], axis=1, inplace=True)

dataset.head()
# Out:
#           x         y        x2            y2   arctan      norm  label
# 0  0.000000  0.000000  0.000000  0.000000e+00  0.00000  0.000000      0
# 1  0.005004  0.000100  0.000025  1.003876e-08  0.02002  0.005005      0
# 2  0.010002  0.000401  0.000100  1.605558e-07  0.04004  0.010010      0
# 3  0.014988  0.000901  0.000225  8.122707e-07  0.06006  0.015015      0
# 4  0.019956  0.001601  0.000398  2.564776e-06  0.08008  0.020020      0

# %% [markdown]
# Solucione este problema considerando:
#
# #### a) Um rede perceptron de múltiplas camadas

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential

mlp = Sequential([
    Dense(32, activation='relu', input_shape=(4,)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(2, activation='relu'),
    Dense(1, activation='tanh')
])

mlp.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

mlp.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                160
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 873
# Trainable params: 873
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

history = mlp.fit(
     x_train, y_train,
    epochs=500,
    validation_split=0.1,
    callbacks=[EarlyStopping(monitor='val_loss', patience=10)]
)
# Out:
# 9 - val_accuracy: 0.7750
# Epoch 38/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8167 - val_loss: 0.4077 - val_accuracy: 0.7750
# Epoch 39/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8194 - val_loss: 0.3767 - val_accuracy: 0.7563
# Epoch 40/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3237 - accuracy: 0.8264 - val_loss: 0.3622 - val_accuracy: 0.7437
# Epoch 41/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3165 - accuracy: 0.8354 - val_loss: 0.3742 - val_accuracy: 0.7625
# Epoch 42/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3153 - accuracy: 0.8139 - val_loss: 0.3621 - val_accuracy: 0.7437
# Epoch 43/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3054 - accuracy: 0.8160 - val_loss: 0.3753 - val_accuracy: 0.7688
# Epoch 44/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.3001 - accuracy: 0.8236 - val_loss: 0.3820 - val_accuracy: 0.8188
# Epoch 45/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3009 - accuracy: 0.8160 - val_loss: 0.4144 - val_accuracy: 0.8500
# Epoch 46/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3022 - accuracy: 0.8201 - val_loss: 0.3920 - val_accuracy: 0.7563
# Epoch 47/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2985 - accuracy: 0.8229 - val_loss: 0.3651 - val_accuracy: 0.7625
# Epoch 48/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2921 - accuracy: 0.7965 - val_loss: 0.4313 - val_accuracy: 0.8500
# Epoch 49/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2992 - accuracy: 0.8104 - val_loss: 0.3729 - val_accuracy: 0.7750
# Epoch 50/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2878 - accuracy: 0.8146 - val_loss: 0.3629 - val_accuracy: 0.7625
# Epoch 51/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2821 - accuracy: 0.8139 - val_loss: 0.3567 - val_accuracy: 0.7500
# Epoch 52/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2909 - accuracy: 0.8194 - val_loss: 0.3846 - val_accuracy: 0.7750
# Epoch 53/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2777 - accuracy: 0.8062 - val_loss: 0.3417 - val_accuracy: 0.7250
# Epoch 54/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2795 - accuracy: 0.8049 - val_loss: 0.3719 - val_accuracy: 0.7750
# Epoch 55/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2742 - accuracy: 0.8278 - val_loss: 0.3584 - val_accuracy: 0.7750
# Epoch 56/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2675 - accuracy: 0.8257 - val_loss: 0.3377 - val_accuracy: 0.7563
# Epoch 57/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2693 - accuracy: 0.8243 - val_loss: 0.3309 - val_accuracy: 0.7437
# Epoch 58/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2651 - accuracy: 0.8313 - val_loss: 0.3418 - val_accuracy: 0.8000
# Epoch 59/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2539 - accuracy: 0.8104 - val_loss: 0.3265 - val_accuracy: 0.7625
# Epoch 60/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2485 - accuracy: 0.8368 - val_loss: 0.3343 - val_accuracy: 0.7500
# Epoch 61/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.8451 - val_loss: 0.3271 - val_accuracy: 0.7563
# Epoch 62/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2495 - accuracy: 0.8444 - val_loss: 0.3492 - val_accuracy: 0.8125
# Epoch 63/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2458 - accuracy: 0.8597 - val_loss: 0.3111 - val_accuracy: 0.7625
# Epoch 64/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2347 - accuracy: 0.8521 - val_loss: 0.3402 - val_accuracy: 0.8562
# Epoch 65/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2413 - accuracy: 0.8701 - val_loss: 0.3184 - val_accuracy: 0.8438
# Epoch 66/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2309 - accuracy: 0.8569 - val_loss: 0.3005 - val_accuracy: 0.8125
# Epoch 67/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2213 - accuracy: 0.8833 - val_loss: 0.2891 - val_accuracy: 0.7625
# Epoch 68/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2177 - accuracy: 0.8674 - val_loss: 0.2848 - val_accuracy: 0.7937
# Epoch 69/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2145 - accuracy: 0.8826 - val_loss: 0.2657 - val_accuracy: 0.8062
# Epoch 70/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2102 - accuracy: 0.8944 - val_loss: 0.2691 - val_accuracy: 0.8500
# Epoch 71/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2106 - accuracy: 0.8896 - val_loss: 0.2818 - val_accuracy: 0.8188
# Epoch 72/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2108 - accuracy: 0.8861 - val_loss: 0.2822 - val_accuracy: 0.8062
# Epoch 73/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2017 - accuracy: 0.9000 - val_loss: 0.2568 - val_accuracy: 0.8250
# Epoch 74/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.2068 - accuracy: 0.8979 - val_loss: 0.2853 - val_accuracy: 0.8250
# Epoch 75/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1967 - accuracy: 0.9014 - val_loss: 0.2784 - val_accuracy: 0.8562
# Epoch 76/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1956 - accuracy: 0.8944 - val_loss: 0.2726 - val_accuracy: 0.8562
# Epoch 77/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1966 - accuracy: 0.9062 - val_loss: 0.2767 - val_accuracy: 0.8562
# Epoch 78/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1924 - accuracy: 0.9076 - val_loss: 0.2726 - val_accuracy: 0.8562
# Epoch 79/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1923 - accuracy: 0.9076 - val_loss: 0.2551 - val_accuracy: 0.8562
# Epoch 80/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1944 - accuracy: 0.9090 - val_loss: 0.2548 - val_accuracy: 0.8562
# Epoch 81/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1910 - accuracy: 0.9056 - val_loss: 0.2771 - val_accuracy: 0.8687
# Epoch 82/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1861 - accuracy: 0.9090 - val_loss: 0.2694 - val_accuracy: 0.8687
# Epoch 83/500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1873 - accuracy: 0.9160 - val_loss: 0.3053 - val_accuracy: 0.8562
# Epoch 84/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1824 - accuracy: 0.9132 - val_loss: 0.2132 - val_accuracy: 0.8938
# Epoch 85/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1730 - accuracy: 0.9118 - val_loss: 0.2504 - val_accuracy: 0.8687
# Epoch 86/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1789 - accuracy: 0.9201 - val_loss: 0.2233 - val_accuracy: 0.9000
# Epoch 87/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1717 - accuracy: 0.9181 - val_loss: 0.2943 - val_accuracy: 0.8625
# Epoch 88/500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.1753 - accuracy: 0.9146 - val_loss: 0.2248 - val_accuracy: 0.8938
# Epoch 89/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1679 - accuracy: 0.9257 - val_loss: 0.2272 - val_accuracy: 0.8687
# Epoch 90/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1588 - accuracy: 0.9306 - val_loss: 0.2099 - val_accuracy: 0.8875
# Epoch 91/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1595 - accuracy: 0.9389 - val_loss: 0.2085 - val_accuracy: 0.9062
# Epoch 92/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1513 - accuracy: 0.9340 - val_loss: 0.1869 - val_accuracy: 0.9187
# Epoch 93/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1485 - accuracy: 0.9347 - val_loss: 0.1907 - val_accuracy: 0.9312
# Epoch 94/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1385 - accuracy: 0.9396 - val_loss: 0.1742 - val_accuracy: 0.9187
# Epoch 95/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9424 - val_loss: 0.1608 - val_accuracy: 0.9625
# Epoch 96/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1316 - accuracy: 0.9521 - val_loss: 0.1691 - val_accuracy: 0.9312
# Epoch 97/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9535 - val_loss: 0.1599 - val_accuracy: 0.9375
# Epoch 98/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1287 - accuracy: 0.9479 - val_loss: 0.1567 - val_accuracy: 0.9375
# Epoch 99/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 0.9458 - val_loss: 0.1757 - val_accuracy: 0.9187
# Epoch 100/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1286 - accuracy: 0.9431 - val_loss: 0.1596 - val_accuracy: 0.9375
# Epoch 101/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.1009 - accuracy: 0.9729 - val_loss: 0.1300 - val_accuracy: 0.9688
# Epoch 102/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0932 - accuracy: 0.9743 - val_loss: 0.1388 - val_accuracy: 0.9688
# Epoch 103/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9743 - val_loss: 0.1955 - val_accuracy: 0.8813
# Epoch 104/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0880 - accuracy: 0.9743 - val_loss: 0.1264 - val_accuracy: 0.9688
# Epoch 105/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.9729 - val_loss: 0.1182 - val_accuracy: 0.9688
# Epoch 106/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0734 - accuracy: 0.9833 - val_loss: 0.0949 - val_accuracy: 0.9750
# Epoch 107/500
# 45/45 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9868 - val_loss: 0.1086 - val_accuracy: 0.9688
# Epoch 108/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0538 - accuracy: 0.9958 - val_loss: 0.0825 - val_accuracy: 0.9750
# Epoch 109/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0536 - accuracy: 0.9875 - val_loss: 0.1254 - val_accuracy: 0.9688
# Epoch 110/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9868 - val_loss: 0.0625 - val_accuracy: 0.9750
# Epoch 111/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9951 - val_loss: 0.0523 - val_accuracy: 0.9750
# Epoch 112/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.9986 - val_loss: 0.0461 - val_accuracy: 0.9812
# Epoch 113/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 0.9972 - val_loss: 0.0491 - val_accuracy: 0.9812
# Epoch 114/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 0.9979 - val_loss: 0.0336 - val_accuracy: 0.9875
# Epoch 115/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 0.0214 - val_accuracy: 0.9875
# Epoch 116/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 0.9993 - val_loss: 0.0286 - val_accuracy: 0.9875
# Epoch 117/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 0.9993 - val_loss: 0.0211 - val_accuracy: 0.9875
# Epoch 118/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 0.9875
# Epoch 119/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0061 - accuracy: 0.9993 - val_loss: 0.0169 - val_accuracy: 0.9875
# Epoch 120/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 121/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 122/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 123/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9937
# Epoch 124/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9937
# Epoch 125/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 126/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 127/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 128/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 129/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 130/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 131/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 132/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 133/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 134/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9937
# Epoch 135/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9937
# Epoch 136/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 137/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 138/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 139/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 140/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9993 - val_loss: 0.0137 - val_accuracy: 0.9875
# Epoch 141/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 6.1371e-04 - val_accuracy: 1.0000
# Epoch 142/500
# 45/45 [==============================] - 0s 3ms/step - loss: 8.0041e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 143/500
# 45/45 [==============================] - 0s 3ms/step - loss: 9.7555e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 144/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 6.3159e-04 - val_accuracy: 1.0000
# Epoch 145/500
# 45/45 [==============================] - 0s 3ms/step - loss: 8.7716e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 146/500
# 45/45 [==============================] - 0s 4ms/step - loss: 9.3980e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 147/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.5651e-04 - val_accuracy: 1.0000
# Epoch 148/500
# 45/45 [==============================] - 0s 3ms/step - loss: 8.1126e-04 - accuracy: 1.0000 - val_loss: 7.1095e-04 - val_accuracy: 1.0000
# Epoch 149/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 150/500
# 45/45 [==============================] - 0s 3ms/step - loss: 5.7986e-04 - accuracy: 1.0000 - val_loss: 5.2123e-04 - val_accuracy: 1.0000
# Epoch 151/500
# 45/45 [==============================] - 0s 3ms/step - loss: 6.4320e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 152/500
# 45/45 [==============================] - 0s 3ms/step - loss: 7.0156e-04 - accuracy: 1.0000 - val_loss: 6.6235e-04 - val_accuracy: 1.0000
# Epoch 153/500
# 45/45 [==============================] - 0s 3ms/step - loss: 4.9321e-04 - accuracy: 1.0000 - val_loss: 5.6744e-04 - val_accuracy: 1.0000
# Epoch 154/500
# 45/45 [==============================] - 0s 3ms/step - loss: 4.9383e-04 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 155/500
# 45/45 [==============================] - 0s 3ms/step - loss: 8.6604e-04 - accuracy: 1.0000 - val_loss: 9.6858e-04 - val_accuracy: 1.0000
# Epoch 156/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 157/500
# 45/45 [==============================] - 0s 3ms/step - loss: 5.8344e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 158/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 159/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 160/500
# 45/45 [==============================] - 0s 3ms/step - loss: 5.3762e-04 - accuracy: 1.0000 - val_loss: 3.4426e-04 - val_accuracy: 1.0000
# Epoch 161/500
# 45/45 [==============================] - 0s 3ms/step - loss: 3.3709e-04 - accuracy: 1.0000 - val_loss: 5.5968e-04 - val_accuracy: 1.0000
# Epoch 162/500
# 45/45 [==============================] - 0s 3ms/step - loss: 7.2211e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 163/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 8.6316e-04 - val_accuracy: 1.0000
# Epoch 164/500
# 45/45 [==============================] - 0s 3ms/step - loss: 8.5925e-04 - accuracy: 1.0000 - val_loss: 5.0164e-04 - val_accuracy: 1.0000
# Epoch 165/500
# 45/45 [==============================] - 0s 3ms/step - loss: 4.5491e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 166/500
# 45/45 [==============================] - 0s 2ms/step - loss: 3.9003e-04 - accuracy: 1.0000 - val_loss: 2.3932e-04 - val_accuracy: 1.0000
# Epoch 167/500
# 45/45 [==============================] - 0s 3ms/step - loss: 4.3930e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 168/500
# 45/45 [==============================] - 0s 3ms/step - loss: 2.4721e-04 - accuracy: 1.0000 - val_loss: 6.4623e-04 - val_accuracy: 1.0000
# Epoch 169/500
# 45/45 [==============================] - 0s 2ms/step - loss: 3.7972e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 170/500
# 45/45 [==============================] - 0s 3ms/step - loss: 6.6043e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 171/500
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 172/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 173/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.8433e-04 - val_accuracy: 1.0000
# Epoch 174/500
# 45/45 [==============================] - 0s 3ms/step - loss: 6.3695e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 175/500
# 45/45 [==============================] - 0s 3ms/step - loss: 3.7712e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 176/500
# 45/45 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.5624e-04 - val_accuracy: 1.0000

# %%
from matplotlib import pyplot as plt

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 8))
axes = axes.flatten()

axes[0].plot(history.history['accuracy'])

axes[0].set(
    title='Training accuracy',
    ylabel='Accuracy',
    xlabel='Epoch'
)

axes[1].plot(history.history['loss'])

axes[1].set(
    title='Training loss',
    ylabel='Loss',
    xlabel='Epoch'
)

axes[2].plot(history.history['val_accuracy'])

axes[2].set(
    title='Validation accuracy',
    ylabel='Accuracy',
    xlabel='Epoch'
)

axes[3].plot(history.history['val_loss'])

axes[3].set(
    title='Validation loss',
    ylabel='Loss',
    xlabel='Epoch'
)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report

y_pred_mlp = mlp.predict_classes(x_test.drop(['x', 'y'], axis=1)).reshape((len(y_test),))

print('MLP:\n', classification_report(y_test, y_pred_mlp))
# Out:
# WARNING:tensorflow:From <ipython-input-9-b36eea8935d5>:3: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# MLP:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       206
#            1       1.00      1.00      1.00       194
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %%
import seaborn as sns

def test_plot(y_pred, clf):
    fig, axes = plt.subplots(ncols=2, figsize=(22, 10))

    fig.suptitle(clf)

    sns.scatterplot(data=x_test, x='x', y='y', hue=y_test, ax=axes[0])

    axes[0].set(
        title='Test dataset',
        xlabel='x',
        ylabel='y'
    )

    sns.scatterplot(
        data=x_test, x='x', y='y', 
        markers={0: 's', 1: 'X'},
        style=y_pred,
        hue=y_pred,
        ax=axes[1]
    )

    axes[1].set(
        title='Predictions',
        xlabel='x',
        ylabel='y'
    )

    plt.tight_layout()
    plt.show()

test_plot(y_pred_mlp, 'MLP')

# %% [markdown]
# #### b) Uma máquina de vetor de suporte (SVM)

# %%
from sklearn.svm import SVC

svm = SVC()

svm.fit(x_train, y_train)

y_pred_svm = svm.predict(x_test.drop(['x', 'y'], axis=1))

print('SVM:\n', classification_report(y_test, y_pred_svm))
# Out:
# SVM:
#                precision    recall  f1-score   support
#
#            0       0.51      0.44      0.47       206
#            1       0.48      0.55      0.51       194
#
#     accuracy                           0.49       400
#    macro avg       0.50      0.50      0.49       400
# weighted avg       0.50      0.49      0.49       400

# %%
test_plot(y_pred_svm, 'SVM')

# %% [markdown]
# #### c) Um comitê de máquinas

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier
import xgboost as xgb

rf = RandomForestClassifier(
    max_features='sqrt',
    min_samples_split=5,
    min_samples_leaf=4,
    bootstrap=True,
    n_estimators=100,
    max_depth=10,
    n_jobs=-1
)

xboost = xgb.XGBClassifier(
    learning_rate=0.1,  
    n_estimators=300, 
    n_jobs=-1
)

extra_tree = ExtraTreesClassifier(
    n_estimators=250,
    n_jobs=-1
)

voting = VotingClassifier(
    estimators=[
        ('rf', rf), 
        ('xboost', xboost), 
        ('extra_tree', extra_tree)
    ],
    voting='hard'
)

voting.fit(x_train, y_train)

y_pred_voting = voting.predict(x_test.drop(['x', 'y'], axis=1))

print('Voting:\n', classification_report(y_test, y_pred_voting))
# Out:
# Voting:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       206
#            1       1.00      1.00      1.00       194
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %%
test_plot(y_pred_voting, 'Voting Classifier')

# %% [markdown]
# ### Matrizes de confusão

# %%
import itertools

def plot_conf_matrix(conf_matrix, title, ax):  
    cax = ax.matshow(conf_matrix, cmap='magma')

    thresh = 100
    for i, j in itertools.product(range(conf_matrix.shape[0]), range(conf_matrix.shape[1])):   
            ax.text(
                j, i, '{:,}'.format(conf_matrix[i, j]),
                horizontalalignment='center',
                fontsize=24,
                color='black' if conf_matrix[i, j] > thresh else 'white'
            )
    
    fig.colorbar(cax, ax=ax)
    labels = [ 0, 1 ]
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    

    accuracy = np.trace(conf_matrix) / float(np.sum(conf_matrix))
    misclass = 1 - accuracy
    ax.set_title(f'{title}\nAccuracy: {accuracy*100:0.2f}%\n')

    ax.set_xlabel('Predicted')
    ax.set_ylabel('Ground Truth')

# %%
from sklearn.metrics import confusion_matrix

confusion_matrizes = [
    ['MLP', confusion_matrix(y_test, y_pred_mlp)],
    ['SVM', confusion_matrix(y_test, y_pred_svm)],
    ['Voting Classifier', confusion_matrix(y_test, y_pred_voting) ]
]

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(28, 8))

index = 0
for col in range(3):
    clf_label, conf_matrix = confusion_matrizes[index]

    plot_conf_matrix(conf_matrix, clf_label, axes[col])

    index += 1

fig.autofmt_xdate(rotation=-20)
plt.tight_layout()
plt.show()
